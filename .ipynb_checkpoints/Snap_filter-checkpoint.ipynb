# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/drive/My Drive/facial-keypoints-detection.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/test.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
import zipfile

zip_ref = zipfile.ZipFile("/content/training.zip", 'r')
zip_ref.extractall()
zip_ref.close()

# %%
# Importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.patches import Circle
from skimage.io import imshow
import math
import numpy as np
#from read_data import get_train_data, get_test_data, visualize_points
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, Input
from keras.callbacks import ModelCheckpoint
from keras.optimizers import SGD, Adam
from skimage.io import imshow
from os.path import join
import glob
from skimage.io import imread
from skimage.transform import resize
from skimage.color import rgb2gray
import matplotlib.pyplot as plt
from matplotlib.patches import Circle

# %%
# Check if row has any NaN values 
def has_nan(keypoints):
    for i in range(len(keypoints)):
        if math.isnan(keypoints[i]):
            return True
    return False

# %%
# Function which plots an image with it's corresponding keypoints
def visualize_points(img, points):
    fig,ax = plt.subplots(1)
    ax.set_aspect('equal')
    imshow(img)
    for i in range(0,len(points),2):
        x_renorm = (points[i]+0.5)*96       # Denormalize x-coordinate
        y_renorm = (points[i+1]+0.5)*96     # Denormalize y-coordinate
        circ = Circle((x_renorm, y_renorm),1, color='r')    # Plot the keypoints at the x and y coordinates
        ax.add_patch(circ)
    plt.show()

# %%
# Read the data as Dataframes
training = pd.read_csv('/content/training.csv')
test = pd.read_csv('/content/test.csv')

# %%
# Get training data
imgs_train = []
points_train = []
for i in range(len(training)):
    points = training.iloc[i,:-1]
    if has_nan(points) is False:
        test_image = training.iloc[i,-1]        # Get the image data
        test_image = np.array(test_image.split(' ')).astype(int)    
        test_image = np.reshape(test_image, (96,96))        # Reshape into an array of size 96x96
        test_image = test_image/255         # Normalize image
        imgs_train.append(test_image)
        
        keypoints = training.iloc[i,:-1].astype(int).values
        keypoints = keypoints/96 - 0.5  # Normalize keypoint coordinates
        points_train.append(keypoints)

# %%
imgs_train = np.array(imgs_train)    
points_train = np.array(points_train)

# %%
# Get test data
imgs_test = []
for i in range(len(test)):
    test_image = test.iloc[i,-1]        # Get the image data
    test_image = np.array(test_image.split(' ')).astype(int)
    test_image = np.reshape(test_image, (96,96))        # Reshape into an array of size 96x96
    test_image = test_image/255     # Normalize image
    imgs_test.append(test_image)

# %%
imgs_test = np.array(imgs_test)

# %%
# Data Augmentation by mirroring the images
def augment(img, points):
    f_img = img[:, ::-1]        # Mirror the image
    for i in range(0,len(points),2):        # Mirror the key point coordinates
        x_renorm = (points[i]+0.5)*96       # Denormalize x-coordinate
        dx = x_renorm - 48          # Get distance to midpoint
        x_renorm_flipped = x_renorm - 2*dx      
        points[i] = x_renorm_flipped/96 - 0.5       # Normalize x-coordinate
    return f_img, points

# %%
aug_imgs_train = []
aug_points_train = []
for i, img in enumerate(imgs_train):
    f_img, f_points = augment(img, points_train[i])
    aug_imgs_train.append(f_img)
    aug_points_train.append(f_points)

# %%
aug_imgs_train = np.array(aug_imgs_train)
aug_points_train = np.array(aug_points_train)

# %%
# Combine the original data and augmented data
imgs_total = np.concatenate((imgs_train, aug_imgs_train), axis=0)       
points_total = np.concatenate((points_train, aug_points_train), axis=0)

# %%
def get_train_data():
    imgs_total_reshaped = np.reshape(imgs_total, (imgs_total.shape[0],imgs_total.shape[1],imgs_total.shape[2], 1))
    return imgs_total_reshaped,points_total

# %%
def get_test_data():
    return imgs_test

# %%
# Get the preprocessed train and test data
imgs_train, points_train = get_train_data()
imgs_test = get_test_data()

# %%
# Define the architecture
def get_model():
    model = Sequential()
    model.add(Conv2D(64, kernel_size=3, strides=2, padding='same', input_shape=(96,96,1), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(Conv2D(128, kernel_size=3, strides=2, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(Conv2D(64, kernel_size=1, strides=2, padding='same', activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))
    model.add(Flatten())
    
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.2))
    model.add(Dense(256, activation='relu'))
    model.add(Dropout(0.1))
    model.add(Dense(30))
    return model;

# %%
# Compile the model
def compile_model(model):       
    model.compile(loss='mean_absolute_error', optimizer='adam', metrics = ['accuracy'])

# %%
 # Fit the model
def train_model(model):        
    # checkpoint = ModelCheckpoint(filepath='weights/checkpoint-{epoch:02d}.hdf5')
    model.fit(imgs_train, points_train, epochs=300, batch_size=100)

# %%
# Train the model
model = get_model()

# %%
compile_model(model)

# %%
train_model(model)
# Out:
# Epoch 1/300
# 4280/4280 [==============================] - 2s 380us/step - loss: 0.0516 - accuracy: 0.4129
# Epoch 2/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0283 - accuracy: 0.5086
# Epoch 3/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0267 - accuracy: 0.5124
# Epoch 4/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0257 - accuracy: 0.5227
# Epoch 5/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0249 - accuracy: 0.5196
# Epoch 6/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0240 - accuracy: 0.5463
# Epoch 7/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0227 - accuracy: 0.5572
# Epoch 8/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0218 - accuracy: 0.6042
# Epoch 9/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0212 - accuracy: 0.6210
# Epoch 10/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0207 - accuracy: 0.6474
# Epoch 11/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0203 - accuracy: 0.6584
# Epoch 12/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0198 - accuracy: 0.6706
# Epoch 13/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0194 - accuracy: 0.6771
# Epoch 14/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0190 - accuracy: 0.6771
# Epoch 15/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0186 - accuracy: 0.6935
# Epoch 16/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0183 - accuracy: 0.6834
# Epoch 17/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0182 - accuracy: 0.6846
# Epoch 18/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0176 - accuracy: 0.6907
# Epoch 19/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0174 - accuracy: 0.7028
# Epoch 20/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0172 - accuracy: 0.7021
# Epoch 21/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0168 - accuracy: 0.7061
# Epoch 22/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0166 - accuracy: 0.7124
# Epoch 23/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0164 - accuracy: 0.7112
# Epoch 24/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0162 - accuracy: 0.7114
# Epoch 25/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0161 - accuracy: 0.7131
# Epoch 26/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0160 - accuracy: 0.7171
# Epoch 27/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0157 - accuracy: 0.7245
# Epoch 28/300
# 4280/4280 [==============================] - 1s 303us/step - loss: 0.0154 - accuracy: 0.7362
# Epoch 29/300
# 4280/4280 [==============================] - 1s 302us/step - loss: 0.0153 - accuracy: 0.7304
# Epoch 30/300
# 4280/4280 [==============================] - 1s 301us/step - loss: 0.0152 - accuracy: 0.7353
# Epoch 31/300
# 4280/4280 [==============================] - 1s 303us/step - loss: 0.0149 - accuracy: 0.7371
# Epoch 32/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0149 - accuracy: 0.7393
# Epoch 33/300
# 4280/4280 [==============================] - 1s 290us/step - loss: 0.0147 - accuracy: 0.7442
# Epoch 34/300
# 4280/4280 [==============================] - 1s 289us/step - loss: 0.0148 - accuracy: 0.7430
# Epoch 35/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0145 - accuracy: 0.7390
# Epoch 36/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0144 - accuracy: 0.7444
# Epoch 37/300
# 4280/4280 [==============================] - 1s 289us/step - loss: 0.0143 - accuracy: 0.7512
# Epoch 38/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0141 - accuracy: 0.7449
# Epoch 39/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0140 - accuracy: 0.7491
# Epoch 40/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0138 - accuracy: 0.7591
# Epoch 41/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0136 - accuracy: 0.7526
# Epoch 42/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0137 - accuracy: 0.7528
# Epoch 43/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0135 - accuracy: 0.7493
# Epoch 44/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0134 - accuracy: 0.7570
# Epoch 45/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0135 - accuracy: 0.7544
# Epoch 46/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0134 - accuracy: 0.7607
# Epoch 47/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0132 - accuracy: 0.7696
# Epoch 48/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0131 - accuracy: 0.7593
# Epoch 49/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0129 - accuracy: 0.7715
# Epoch 50/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0129 - accuracy: 0.7731
# Epoch 51/300
# 4280/4280 [==============================] - 1s 290us/step - loss: 0.0129 - accuracy: 0.7652
# Epoch 52/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0129 - accuracy: 0.7650
# Epoch 53/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0128 - accuracy: 0.7664
# Epoch 54/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0127 - accuracy: 0.7633
# Epoch 55/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0127 - accuracy: 0.7640
# Epoch 56/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0125 - accuracy: 0.7748
# Epoch 57/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0125 - accuracy: 0.7717
# Epoch 58/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0125 - accuracy: 0.7825
# Epoch 59/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0124 - accuracy: 0.7825
# Epoch 60/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0124 - accuracy: 0.7857
# Epoch 61/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0123 - accuracy: 0.7752
# Epoch 62/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0122 - accuracy: 0.7843
# Epoch 63/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0123 - accuracy: 0.7834
# Epoch 64/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0121 - accuracy: 0.7797
# Epoch 65/300
# 4280/4280 [==============================] - 1s 290us/step - loss: 0.0120 - accuracy: 0.7790
# Epoch 66/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0120 - accuracy: 0.7907
# Epoch 67/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0119 - accuracy: 0.7853
# Epoch 68/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0118 - accuracy: 0.7883
# Epoch 69/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0118 - accuracy: 0.7806
# Epoch 70/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0117 - accuracy: 0.7970
# Epoch 71/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0117 - accuracy: 0.7960
# Epoch 72/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0117 - accuracy: 0.7942
# Epoch 73/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0116 - accuracy: 0.7909
# Epoch 74/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0116 - accuracy: 0.7862
# Epoch 75/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0116 - accuracy: 0.8007
# Epoch 76/300
# 4280/4280 [==============================] - 1s 290us/step - loss: 0.0116 - accuracy: 0.7965
# Epoch 77/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0115 - accuracy: 0.7932
# Epoch 78/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0115 - accuracy: 0.8037
# Epoch 79/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0114 - accuracy: 0.7890
# Epoch 80/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0114 - accuracy: 0.7972
# Epoch 81/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0114 - accuracy: 0.7970
# Epoch 82/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0114 - accuracy: 0.7977
# Epoch 83/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0113 - accuracy: 0.7918
# Epoch 84/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0112 - accuracy: 0.7953
# Epoch 85/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0111 - accuracy: 0.7944
# Epoch 86/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0111 - accuracy: 0.7986
# Epoch 87/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0111 - accuracy: 0.8044
# Epoch 88/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0111 - accuracy: 0.8000
# Epoch 89/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0111 - accuracy: 0.8105
# Epoch 90/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0110 - accuracy: 0.7988
# Epoch 91/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0109 - accuracy: 0.8044
# Epoch 92/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0110 - accuracy: 0.8028
# Epoch 93/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0110 - accuracy: 0.8005
# Epoch 94/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0109 - accuracy: 0.8056
# Epoch 95/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0108 - accuracy: 0.8054
# Epoch 96/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0108 - accuracy: 0.8107
# Epoch 97/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0107 - accuracy: 0.8157
# Epoch 98/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0108 - accuracy: 0.8061
# Epoch 99/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0107 - accuracy: 0.8126
# Epoch 100/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0107 - accuracy: 0.8079
# Epoch 101/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0107 - accuracy: 0.8082
# Epoch 102/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0107 - accuracy: 0.8058
# Epoch 103/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0106 - accuracy: 0.8133
# Epoch 104/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0105 - accuracy: 0.8150
# Epoch 105/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0105 - accuracy: 0.8107
# Epoch 106/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0105 - accuracy: 0.8147
# Epoch 107/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0106 - accuracy: 0.8075
# Epoch 108/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0105 - accuracy: 0.8187
# Epoch 109/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0104 - accuracy: 0.8152
# Epoch 110/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0104 - accuracy: 0.8040
# Epoch 111/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0104 - accuracy: 0.8051
# Epoch 112/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0104 - accuracy: 0.8007
# Epoch 113/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0104 - accuracy: 0.8150
# Epoch 114/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0103 - accuracy: 0.8175
# Epoch 115/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0103 - accuracy: 0.8030
# Epoch 116/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0102 - accuracy: 0.8121
# Epoch 117/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0103 - accuracy: 0.8189
# Epoch 118/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0102 - accuracy: 0.8171
# Epoch 119/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0103 - accuracy: 0.8112
# Epoch 120/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0103 - accuracy: 0.8112
# Epoch 121/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0101 - accuracy: 0.8187
# Epoch 122/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0102 - accuracy: 0.8243
# Epoch 123/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0102 - accuracy: 0.8220
# Epoch 124/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0102 - accuracy: 0.8171
# Epoch 125/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0101 - accuracy: 0.8164
# Epoch 126/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0101 - accuracy: 0.8257
# Epoch 127/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0100 - accuracy: 0.8241
# Epoch 128/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0100 - accuracy: 0.8166
# Epoch 129/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0100 - accuracy: 0.8166
# Epoch 130/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0100 - accuracy: 0.8217
# Epoch 131/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0100 - accuracy: 0.8220
# Epoch 132/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0101 - accuracy: 0.8180
# Epoch 133/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0100 - accuracy: 0.8217
# Epoch 134/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0100 - accuracy: 0.8213
# Epoch 135/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0100 - accuracy: 0.8217
# Epoch 136/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0099 - accuracy: 0.8145
# Epoch 137/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0099 - accuracy: 0.8283
# Epoch 138/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0099 - accuracy: 0.8182
# Epoch 139/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0100 - accuracy: 0.8250
# Epoch 140/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0098 - accuracy: 0.8203
# Epoch 141/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0098 - accuracy: 0.8283
# Epoch 142/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0098 - accuracy: 0.8227
# Epoch 143/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0097 - accuracy: 0.8287
# Epoch 144/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0098 - accuracy: 0.8234
# Epoch 145/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0098 - accuracy: 0.8245
# Epoch 146/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0098 - accuracy: 0.8280
# Epoch 147/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0098 - accuracy: 0.8283
# Epoch 148/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0097 - accuracy: 0.8234
# Epoch 149/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0097 - accuracy: 0.8280
# Epoch 150/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0097 - accuracy: 0.8227
# Epoch 151/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0098 - accuracy: 0.8224
# Epoch 152/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0097 - accuracy: 0.8350
# Epoch 153/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0097 - accuracy: 0.8262
# Epoch 154/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0097 - accuracy: 0.8301
# Epoch 155/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0096 - accuracy: 0.8264
# Epoch 156/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0097 - accuracy: 0.8220
# Epoch 157/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0097 - accuracy: 0.8306
# Epoch 158/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0096 - accuracy: 0.8292
# Epoch 159/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0096 - accuracy: 0.8313
# Epoch 160/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0096 - accuracy: 0.8320
# Epoch 161/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0096 - accuracy: 0.8229
# Epoch 162/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0096 - accuracy: 0.8339
# Epoch 163/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0095 - accuracy: 0.8315
# Epoch 164/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0095 - accuracy: 0.8369
# Epoch 165/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0095 - accuracy: 0.8297
# Epoch 166/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0095 - accuracy: 0.8273
# Epoch 167/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0095 - accuracy: 0.8313
# Epoch 168/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0094 - accuracy: 0.8315
# Epoch 169/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0094 - accuracy: 0.8329
# Epoch 170/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0095 - accuracy: 0.8381
# Epoch 171/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0094 - accuracy: 0.8311
# Epoch 172/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0095 - accuracy: 0.8308
# Epoch 173/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0094 - accuracy: 0.8304
# Epoch 174/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0094 - accuracy: 0.8306
# Epoch 175/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0094 - accuracy: 0.8287
# Epoch 176/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0094 - accuracy: 0.8273
# Epoch 177/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0094 - accuracy: 0.8201
# Epoch 178/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0094 - accuracy: 0.8278
# Epoch 179/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0094 - accuracy: 0.8301
# Epoch 180/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0094 - accuracy: 0.8308
# Epoch 181/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0094 - accuracy: 0.8374
# Epoch 182/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0094 - accuracy: 0.8341
# Epoch 183/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0093 - accuracy: 0.8297
# Epoch 184/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0094 - accuracy: 0.8290
# Epoch 185/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0093 - accuracy: 0.8301
# Epoch 186/300
# 4280/4280 [==============================] - 1s 299us/step - loss: 0.0094 - accuracy: 0.8411
# Epoch 187/300
# 4280/4280 [==============================] - 1s 300us/step - loss: 0.0094 - accuracy: 0.8262
# Epoch 188/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0093 - accuracy: 0.8325
# Epoch 189/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0093 - accuracy: 0.8390
# Epoch 190/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0093 - accuracy: 0.8292
# Epoch 191/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0092 - accuracy: 0.8362
# Epoch 192/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0091 - accuracy: 0.8292
# Epoch 193/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0092 - accuracy: 0.8374
# Epoch 194/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0092 - accuracy: 0.8343
# Epoch 195/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0092 - accuracy: 0.8313
# Epoch 196/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0092 - accuracy: 0.8343
# Epoch 197/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8367
# Epoch 198/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0091 - accuracy: 0.8388
# Epoch 199/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8357
# Epoch 200/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8376
# Epoch 201/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0092 - accuracy: 0.8409
# Epoch 202/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0091 - accuracy: 0.8374
# Epoch 203/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0092 - accuracy: 0.8402
# Epoch 204/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8346
# Epoch 205/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8299
# Epoch 206/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0091 - accuracy: 0.8355
# Epoch 207/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0091 - accuracy: 0.8346
# Epoch 208/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0090 - accuracy: 0.8379
# Epoch 209/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0091 - accuracy: 0.8315
# Epoch 210/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0090 - accuracy: 0.8318
# Epoch 211/300
# 4280/4280 [==============================] - 1s 300us/step - loss: 0.0091 - accuracy: 0.8350
# Epoch 212/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0091 - accuracy: 0.8376
# Epoch 213/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0091 - accuracy: 0.8444
# Epoch 214/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0091 - accuracy: 0.8437
# Epoch 215/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0091 - accuracy: 0.8362
# Epoch 216/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0091 - accuracy: 0.8332
# Epoch 217/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0090 - accuracy: 0.8428
# Epoch 218/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0091 - accuracy: 0.8339
# Epoch 219/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0090 - accuracy: 0.8360
# Epoch 220/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0090 - accuracy: 0.8400
# Epoch 221/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0091 - accuracy: 0.8446
# Epoch 222/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0090 - accuracy: 0.8397
# Epoch 223/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0090 - accuracy: 0.8374
# Epoch 224/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0090 - accuracy: 0.8418
# Epoch 225/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0090 - accuracy: 0.8343
# Epoch 226/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0090 - accuracy: 0.8430
# Epoch 227/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0089 - accuracy: 0.8357
# Epoch 228/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0090 - accuracy: 0.8407
# Epoch 229/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0089 - accuracy: 0.8397
# Epoch 230/300
# 4280/4280 [==============================] - 1s 305us/step - loss: 0.0089 - accuracy: 0.8411
# Epoch 231/300
# 4280/4280 [==============================] - 1s 305us/step - loss: 0.0090 - accuracy: 0.8430
# Epoch 232/300
# 4280/4280 [==============================] - 1s 308us/step - loss: 0.0089 - accuracy: 0.8488
# Epoch 233/300
# 4280/4280 [==============================] - 1s 304us/step - loss: 0.0089 - accuracy: 0.8404
# Epoch 234/300
# 4280/4280 [==============================] - 1s 307us/step - loss: 0.0089 - accuracy: 0.8407
# Epoch 235/300
# 4280/4280 [==============================] - 1s 306us/step - loss: 0.0088 - accuracy: 0.8493
# Epoch 236/300
# 4280/4280 [==============================] - 1s 306us/step - loss: 0.0089 - accuracy: 0.8444
# Epoch 237/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0089 - accuracy: 0.8388
# Epoch 238/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0089 - accuracy: 0.8325
# Epoch 239/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0088 - accuracy: 0.8341
# Epoch 240/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0089 - accuracy: 0.8393
# Epoch 241/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0089 - accuracy: 0.8318
# Epoch 242/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0089 - accuracy: 0.8428
# Epoch 243/300
# 4280/4280 [==============================] - 1s 300us/step - loss: 0.0088 - accuracy: 0.8311
# Epoch 244/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0089 - accuracy: 0.8465
# Epoch 245/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8418
# Epoch 246/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0088 - accuracy: 0.8364
# Epoch 247/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8421
# Epoch 248/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0088 - accuracy: 0.8467
# Epoch 249/300
# 4280/4280 [==============================] - 1s 290us/step - loss: 0.0088 - accuracy: 0.8411
# Epoch 250/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0088 - accuracy: 0.8409
# Epoch 251/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0088 - accuracy: 0.8371
# Epoch 252/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0088 - accuracy: 0.8402
# Epoch 253/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0088 - accuracy: 0.8386
# Epoch 254/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0087 - accuracy: 0.8491
# Epoch 255/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0087 - accuracy: 0.8500
# Epoch 256/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0087 - accuracy: 0.8437
# Epoch 257/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0087 - accuracy: 0.8509
# Epoch 258/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8395
# Epoch 259/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8402
# Epoch 260/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0088 - accuracy: 0.8393
# Epoch 261/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0088 - accuracy: 0.8446
# Epoch 262/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0088 - accuracy: 0.8425
# Epoch 263/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0087 - accuracy: 0.8463
# Epoch 264/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0088 - accuracy: 0.8493
# Epoch 265/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0089 - accuracy: 0.8402
# Epoch 266/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8463
# Epoch 267/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0088 - accuracy: 0.8456
# Epoch 268/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0087 - accuracy: 0.8467
# Epoch 269/300
# 4280/4280 [==============================] - 1s 301us/step - loss: 0.0087 - accuracy: 0.8523
# Epoch 270/300
# 4280/4280 [==============================] - 1s 309us/step - loss: 0.0087 - accuracy: 0.8451
# Epoch 271/300
# 4280/4280 [==============================] - 1s 306us/step - loss: 0.0087 - accuracy: 0.8521
# Epoch 272/300
# 4280/4280 [==============================] - 1s 304us/step - loss: 0.0087 - accuracy: 0.8474
# Epoch 273/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0087 - accuracy: 0.8442
# Epoch 274/300
# 4280/4280 [==============================] - 1s 298us/step - loss: 0.0087 - accuracy: 0.8402
# Epoch 275/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0088 - accuracy: 0.8390
# Epoch 276/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0088 - accuracy: 0.8442
# Epoch 277/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0086 - accuracy: 0.8453
# Epoch 278/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0087 - accuracy: 0.8428
# Epoch 279/300
# 4280/4280 [==============================] - 1s 297us/step - loss: 0.0087 - accuracy: 0.8458
# Epoch 280/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0087 - accuracy: 0.8507
# Epoch 281/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0087 - accuracy: 0.8416
# Epoch 282/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0087 - accuracy: 0.8477
# Epoch 283/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0086 - accuracy: 0.8418
# Epoch 284/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0087 - accuracy: 0.8409
# Epoch 285/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0087 - accuracy: 0.8467
# Epoch 286/300
# 4280/4280 [==============================] - 1s 294us/step - loss: 0.0086 - accuracy: 0.8465
# Epoch 287/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0086 - accuracy: 0.8502
# Epoch 288/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0087 - accuracy: 0.8437
# Epoch 289/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0086 - accuracy: 0.8519
# Epoch 290/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0086 - accuracy: 0.8409
# Epoch 291/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0085 - accuracy: 0.8437
# Epoch 292/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0086 - accuracy: 0.8467
# Epoch 293/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0087 - accuracy: 0.8421
# Epoch 294/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0086 - accuracy: 0.8458
# Epoch 295/300
# 4280/4280 [==============================] - 1s 295us/step - loss: 0.0086 - accuracy: 0.8481
# Epoch 296/300
# 4280/4280 [==============================] - 1s 296us/step - loss: 0.0085 - accuracy: 0.8402
# Epoch 297/300
# 4280/4280 [==============================] - 1s 293us/step - loss: 0.0085 - accuracy: 0.8383
# Epoch 298/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0086 - accuracy: 0.8467
# Epoch 299/300
# 4280/4280 [==============================] - 1s 292us/step - loss: 0.0086 - accuracy: 0.8409
# Epoch 300/300
# 4280/4280 [==============================] - 1s 291us/step - loss: 0.0086 - accuracy: 0.8479

# %%
model.save('Snap_filter.h5')
